# %%
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from tabulate import tabulate
from matplotlib import gridspec
import imageio
from IPython.display import Video

from src.encoder_seq import VICRegJEPAEncoder
from src.data.dataset import PointMazeSequences

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# Load the dataset

# %%
dataset = PointMazeSequences(
    "data/train_trajectories_10_100_4_64_largerdot.npz",
    normalize=True,
    seq_len=5
)
# Out:
# [Dataset] 200 sequences from 10 episodes, seq_len=5, stride=5

# %% [markdown]
# Load the model

# %%
visual_encoder = VICRegJEPAEncoder.load_from_checkpoint("checkpoints/visual_encoder/last.ckpt", strict=False)
visual_encoder.to(device)
visual_encoder.eval();

# %%
save_nets = False
if save_nets:
    base_path = "checkpoints/pth/"
    torch.save(visual_encoder.visual_encoder.state_dict(), base_path + "visual_encoder.pth")
    torch.save(visual_encoder.proprio_encoder.state_dict(), base_path + "proprio_encoder.pth")
    torch.save(visual_encoder.visual_decoder.state_dict(), base_path + "visual_decoder.pth")
    torch.save(visual_encoder.proprio_decoder.state_dict(), base_path + "proprio_decoder.pth")

# %% [markdown]
# Encoding decoding

# %%
idx = 1

# %%
states, frames, actions = dataset[idx]

with torch.no_grad():
    # move inputs to device and use bfloat16 autocast for enc/dec
    with torch.amp.autocast(dtype=torch.bfloat16, device_type=device.type):
        states = states.to(device)          # (1, T, state_dim)
        frames = frames.to(device)          # (1, T, C, H, W)
        actions = actions.to(device)        # (1, T, action_dim)

        z_states = visual_encoder.proprio_encoder(states)    # (1, T, D)
        z_cls, z_patches, _ = visual_encoder.visual_encoder(frames)  # (1, T, N, D)

        states_recon = visual_encoder.proprio_decoder(z_states)
        frames_recon = visual_encoder.visual_decoder(z_patches)

frames = frames.permute(0, 2, 3, 1).float().cpu().numpy()
frames_recon = frames_recon.permute(0, 2, 3, 1).float().cpu().numpy()

# %%
# Visualize original and reconstructed frames
n_frames = frames.shape[0]
fig = plt.figure(figsize=(12, 4))
gs = gridspec.GridSpec(2, n_frames, figure=fig)
for t in range(n_frames):
    ax_orig = fig.add_subplot(gs[0, t])
    ax_orig.imshow(frames[0])
    ax_orig.axis("off")

    ax_recon = fig.add_subplot(gs[1, t])
    ax_recon.imshow(frames_recon[0])
    ax_recon.axis("off")
plt.tight_layout()
plt.show()

# %%
batch = torch.stack([img_curr, img_next], dim=0)  # (B, 3, 64, 64)
batch_pred = torch.stack([img_curr_recon, img_next_recon], dim=0)  # (B, 3, 64, 64)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 batch = torch.stack([img_curr, img_next], dim=0)  # (B, 3, 64, 64)
#       2 batch_pred = torch.stack([img_curr_recon, img_next_recon], dim=0)  # (B, 3, 64, 64)
#
# NameError: name 'img_curr' is not defined

# %%
(batch - batch_pred).mean(1).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 (batch - batch_pred).mean(1).shape
#
# NameError: name 'batch' is not defined

# %%
def patch_weighted_recon_loss(pred, target, patch_size=8, eps=1e-6):
    B, C, H, W = pred.shape
    ph = H // patch_size
    pw = W // patch_size

    # reshape into patches
    pred_p = pred.unfold(2, patch_size, patch_size).unfold(3, patch_size, patch_size)  # (B,C,ph,pw,P,P)
    tgt_p  = target.unfold(2, patch_size, patch_size).unfold(3, patch_size, patch_size)

    mse_per_patch = ((pred_p - tgt_p) ** 2).mean(dim=(1,5,6))        # (B, ph, pw)

    # normalize weights between patches within each image
    weights = mse_per_patch / (mse_per_patch.sum(dim=(1,2), keepdim=True) + eps)

    # weighted sum of per-patch MSE
    loss = (weights * mse_per_patch).sum(dim=(1,2))                  # (B,)
    return loss.mean()

# %%
diff = (z_patches_next - z_patches_curr)[0].abs().cpu().detach().numpy().mean(axis=1)
# softmax with temperature T
T = .5
diff = np.exp(diff / T) / np.sum(np.exp(diff / T))
# get first k indices with highest difference
k = 2
topk_indices = np.argsort(-diff)[:k]
print(f"Top {k} patches with highest difference indices: {topk_indices}")
print(f"Values: {diff[topk_indices].sum():.1%}")
# normalize for better visualization
plt.figure(figsize=(4, 3))
plt.title("Patch Differences between Current and Next Frame")
plt.bar(np.arange(len(diff)), diff)
plt.xlabel("Patch Index")
plt.ylabel("Mean Absolute Difference")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 diff = (z_patches_next - z_patches_curr)[0].abs().cpu().detach().numpy().mean(axis=1)
#       2 # softmax with temperature T
#       3 T = .5
#
# NameError: name 'z_patches_next' is not defined

# %% [markdown]
# Define helpful methods

# %%
def show_reconstruction(idx):
    # Load data
    (proprio_curr, img_curr), action, (proprio_next, img_next), _ = dataset[idx]
    
    # Prepare inputs
    imgs = {
        'curr': img_curr.unsqueeze(0).to(device),
        'next': img_next.unsqueeze(0).to(device)
    }
    proprios = {
        'curr': proprio_curr.unsqueeze(0).to(device),
        'next': proprio_next.unsqueeze(0).to(device)
    }
    action = action.unsqueeze(0).to(device)
    
    # Run inference
    with torch.no_grad():
        encodings = _encode_states(imgs, proprios)
        reconstructions = _reconstruct_states(encodings)
        predictions = _predict_next_state(encodings, action)
    
    # Display results
    _print_proprio_table(proprios, reconstructions)
    _plot_images(imgs, reconstructions, predictions)

    return encodings, reconstructions, predictions


def _encode_states(imgs, proprios):
    """Encode visual and proprioceptive states."""
    with torch.amp.autocast(dtype=torch.bfloat16, device_type=device.type):
        cls_curr, patches_curr, _ = visual_encoder.visual_encoder(imgs['curr'])
        cls_next, patches_next, _ = visual_encoder.visual_encoder(imgs['next'])
    
    return {
        'cls_curr': cls_curr,
        'patches_curr': patches_curr,
        'cls_next': cls_next,
        'patches_next': patches_next,
        'proprio_curr': visual_encoder.proprio_encoder(proprios['curr']),
        'proprio_next': visual_encoder.proprio_encoder(proprios['next'])
    }


def _reconstruct_states(enc):
    """Reconstruct states from encodings."""
    return {
        'img_curr': visual_encoder.visual_decoder(enc['patches_curr'], enc['cls_curr'], enc['proprio_curr']),
        'img_next': visual_encoder.visual_decoder(enc['patches_next'], enc['cls_next'], enc['proprio_next']),
        'proprio_curr': visual_encoder.proprio_decoder(enc['proprio_curr']),
        'proprio_next': visual_encoder.proprio_decoder(enc['proprio_next']),
        'proprio_from_cls_curr': visual_encoder.proprio_decoder(enc['cls_curr']),
        'proprio_from_cls_next': visual_encoder.proprio_decoder(enc['cls_next'])
    }


def _predict_next_state(enc, action):
    """Predict next state from current state and action."""
    with torch.amp.autocast(dtype=torch.bfloat16, device_type=device.type):
        # tokens = torch.cat([enc['cls_curr'].unsqueeze(1), enc['patches_curr']], dim=1)
        action_enc = visual_encoder.action_encoder(action)
        
        # pred_cls, pred_patches, pred_prop = visual_encoder.predictor(
        #     tokens, enc['proprio_curr'], action_enc
        # )
        pred_cls, pred_patches, pred_prop = visual_encoder.predictor(
            enc['patches_curr']
        )
        # pred_cls += enc['cls_curr']
        # pred_patches += enc['patches_curr']
        # pred_prop += enc['proprio_curr']

    with torch.amp.autocast(dtype=torch.bfloat16, device_type=device.type):
        return {
            'cls': visual_encoder.proprio_decoder(pred_cls).float(),
            'proprio': visual_encoder.proprio_decoder(pred_prop).float(),
            'img': visual_encoder.visual_decoder(pred_patches, pred_cls, pred_prop).float()
        }


def _print_proprio_table(proprios, recons):
    """Display proprioceptive data in a table."""
    fmt = lambda x: np.array2string(x.cpu().numpy(), precision=3, suppress_small=True)
    
    table = [
        ["", "Original", "Reconstructed (proprio)", "Reconstructed (visual cls)"],
        ["Current", fmt(proprios['curr']), fmt(recons['proprio_curr']), 
         fmt(recons['proprio_from_cls_curr'])],
        ["Next", fmt(proprios['next']), fmt(recons['proprio_next']), 
         fmt(recons['proprio_from_cls_next'])]
    ]
    
    table_transposed = list(map(list, zip(*table)))
    print(tabulate(table_transposed, headers="firstrow", tablefmt="fancy_grid"))


def _plot_images(imgs, recons, preds):
    """Plot original, reconstructed, and predicted images."""
    to_img = lambda x: x[0].permute(1, 2, 0).cpu()
    
    _, axes = plt.subplots(2, 3, figsize=(10, 6))
    
    # Current state row
    axes[0, 0].imshow(to_img(imgs['curr']))
    axes[0, 0].set_title("Current")
    
    axes[0, 1].imshow(to_img(recons['img_curr']))
    axes[0, 1].set_title("Reconstruction")
    
    axes[0, 2].imshow(torch.ones_like(imgs['curr'])[0].permute(1, 2, 0).cpu())
    axes[0, 2].set_title("White")
    
    # Next state row
    axes[1, 0].imshow(to_img(imgs['next']))
    axes[1, 0].set_title("Next")
    
    axes[1, 1].imshow(to_img(recons['img_next']))
    axes[1, 1].set_title("Reconstruction")
    
    axes[1, 2].imshow(to_img(preds['img']))
    axes[1, 2].set_title("Predicted Next")
    
    for ax in axes.flat:
        ax.axis("off")
    
    plt.tight_layout()
    plt.show()

# %%
encodings, reconstructions, predictions = show_reconstruction(11)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 encodings, reconstructions, predictions = show_reconstruction(11)
#
# Cell In[32], line 3, in show_reconstruction(idx)
#       1 def show_reconstruction(idx):
#       2     # Load data
# ----> 3     (proprio_curr, img_curr), action, (proprio_next, img_next), _ = dataset[idx]
#       5     # Prepare inputs
#       6     imgs = {
#       7         'curr': img_curr.unsqueeze(0).to(device),
#       8         'next': img_next.unsqueeze(0).to(device)
#       9     }
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %%
diff = encodings['patches_next'][0] - encodings['patches_curr'][0]
diff = torch.round(diff, decimals=2)

# Get the top-k changing patches
K = 6
patch_changes = diff.abs().mean(dim=-1)  # (N,)
_, topk_indices = torch.topk(patch_changes, k=K, dim=-1)  # (k,)
plt.figure(figsize=(12, 3))
plt.imshow(diff.cpu().numpy().round(1).T, cmap='bwr', aspect='auto')
plt.colorbar()
plt.title("Top-K Changing Patches Highlighted")
for idx in topk_indices:
    plt.axvline(x=idx.item(), color='k', linestyle='--')
plt.show()

patch_changes_grid = patch_changes.view(8, 8)
plt.figure(figsize=(6, 6))
plt.imshow(patch_changes_grid.cpu().numpy().round(2), cmap='plasma')
plt.colorbar()
plt.title("Patch Changes Magnitude")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 diff = encodings['patches_next'][0] - encodings['patches_curr'][0]
#       2 diff = torch.round(diff, decimals=2)
#       4 # Get the top-k changing patches
#
# NameError: name 'encodings' is not defined

# %%
plt.figure(figsize=(12, 3))
plt.imshow(diff.cpu().numpy().round(1).T, cmap='bwr', aspect='auto')
plt.colorbar()
plt.title("Min-Max Normalized Difference between Next and Current Patch Encodings")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 plt.figure(figsize=(12, 3))
# ----> 2 plt.imshow(diff.cpu().numpy().round(1).T, cmap='bwr', aspect='auto')
#       3 plt.colorbar()
#       4 plt.title("Min-Max Normalized Difference between Next and Current Patch Encodings")
#
# NameError: name 'diff' is not defined

# %%
# Extract a trajectory
horizon = 80
trajectory = [
    dataset[idx][0] for idx in range(horizon)
]

# Compute all the embeddings
proprio_traj = []
cls_traj = []
patches_traj = []
recon_traj = []
with torch.no_grad():
    for (proprio, img) in trajectory:
        img = img.unsqueeze(0).to(device)
        proprio = proprio.unsqueeze(0).to(device)
        with torch.amp.autocast(dtype=torch.float16, device_type=device.type):
            cls, patches, _ = visual_encoder.visual_encoder(img)
            recon = visual_encoder.visual_decoder(patches)
        proprio_traj.append(proprio.cpu())
        cls_traj.append(cls.cpu())
        patches_traj.append(patches.cpu())
        recon_traj.append(recon.cpu())

# Stack
proprio_traj = torch.cat(proprio_traj, dim=0)   # (horizon, D)
cls_traj = torch.cat(cls_traj, dim=0)           # (horizon, E)
patches_traj = torch.cat(patches_traj, dim=0)   # (horizon, P)
recon_traj = torch.cat(recon_traj, dim=0)       # (horizon, P)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 13
#      11 recon_traj = []
#      12 with torch.no_grad():
# ---> 13     for (proprio, img) in trajectory:
#      14         img = img.unsqueeze(0).to(device)
#      15         proprio = proprio.unsqueeze(0).to(device)
#
# ValueError: too many values to unpack (expected 2)

# %%
from sklearn.manifold import TSNE

def twoD_projection(cls_traj):
    tsne = TSNE(n_components=2, perplexity=10, random_state=0)
    return tsne.fit_transform(cls_traj.numpy())

cls_traj_2d = twoD_projection(cls_traj)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 7
#       4     tsne = TSNE(n_components=2, perplexity=10, random_state=0)
#       5     return tsne.fit_transform(cls_traj.numpy())
# ----> 7 cls_traj_2d = twoD_projection(cls_traj)
#
# Cell In[37], line 5, in twoD_projection(cls_traj)
#       3 def twoD_projection(cls_traj):
#       4     tsne = TSNE(n_components=2, perplexity=10, random_state=0)
# ----> 5     return tsne.fit_transform(cls_traj.numpy())
#
# AttributeError: 'list' object has no attribute 'numpy'

# %%
from IPython.display import HTML, display

# Write a practically lossless MP4 for reconstructions (images)
mp4_path = "reconstructed_trajectory_lossless.mp4"
fps = 3

with imageio.get_writer(
    mp4_path,
    fps=fps,
    codec='libx264',
    ffmpeg_params=['-crf', '0', '-preset', 'veryslow', '-pix_fmt', 'yuv444p']
) as writer:
    for t in range(horizon):
        img = recon_traj[t].permute(1,2,0).cpu().float().numpy()   # (H, W, 3), float [0,1]
        img = (img * 255).astype(np.uint8)
        writer.append_data(img)


# Create a video rendering the 2D latent trajectory (rendered with matplotlib)
mp4_path_latent = "reconstructed_trajectory_latent.mp4"

# ensure cls_traj_2d is a numpy array
if not isinstance(cls_traj_2d, np.ndarray):
    cls_xy = cls_traj_2d.cpu().numpy()
else:
    cls_xy = cls_traj_2d

with imageio.get_writer(
    mp4_path_latent,
    fps=fps,
    codec='libx264',
    ffmpeg_params=['-crf', '0', '-preset', 'veryslow', '-pix_fmt', 'yuv444p']
) as writer:
    fig, ax = plt.subplots(figsize=(6,6))
    xmin, xmax = cls_xy[:,0].min(), cls_xy[:,0].max()
    ymin, ymax = cls_xy[:,1].min(), cls_xy[:,1].max()
    # add small padding
    dx = (xmax - xmin) * 0.05 if xmax > xmin else 0.1
    dy = (ymax - ymin) * 0.05 if ymax > ymin else 0.1
    for t in range(horizon):
        ax.clear()
        # faint trajectory line
        ax.plot(cls_xy[:,0], cls_xy[:,1], color='lightgray', linewidth=1, zorder=1)
        # colored points
        ax.scatter(cls_xy[:,0], cls_xy[:,1], c=np.arange(len(cls_xy)), cmap='plasma', s=40, zorder=2)
        # highlight current timestep
        ax.scatter([cls_xy[t,0]], [cls_xy[t,1]], color='red', s=120, zorder=3)
        ax.set_xlim(xmin - dx, xmax + dx)
        ax.set_ylim(ymin - dy, ymax + dy)
        ax.set_title(f"Latent Trajectory (t={t})")
        ax.axis('off')
        fig.canvas.draw()
        w, h = fig.canvas.get_width_height()
        frame = np.frombuffer(fig.canvas.tostring_argb(), dtype=np.uint8).reshape(h, w, 4)
        writer.append_data(frame)
    plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 14
#       7 with imageio.get_writer(
#       8     mp4_path,
#       9     fps=fps,
#      10     codec='libx264',
#      11     ffmpeg_params=['-crf', '0', '-preset', 'veryslow', '-pix_fmt', 'yuv444p']
#      12 ) as writer:
#      13     for t in range(horizon):
# ---> 14         img = recon_traj[t].permute(1,2,0).cpu().float().numpy()   # (H, W, 3), float [0,1]
#      15         img = (img * 255).astype(np.uint8)
#      16         writer.append_data(img)
#
# IndexError: list index out of range

# %%
html = f"""
<div style="display:flex;gap:12px;align-items:flex-start">
  <div style="flex:0 0 auto;text-align:center">
    <div>Reconstructed Images</div>
    <video src="{mp4_path}" controls style="min-width:240px; max-width:240px; height:auto;"></video>
  </div>
  <div style="flex:0 0 auto;text-align:center">
    <div>Latent Trajectory</div>
    <video src="{mp4_path_latent}" controls style="min-width:240px; max-width:240px; height:auto;"></video>
  </div>
</div>
"""
display(HTML(html))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 9
#       1 html = f"""
#       2 <div style="display:flex;gap:12px;align-items:flex-start">
#       3   <div style="flex:0 0 auto;text-align:center">
#       4     <div>Reconstructed Images</div>
#       5     <video src="{mp4_path}" controls style="min-width:240px; max-width:240px; height:auto;"></video>
#       6   </div>
#       7   <div style="flex:0 0 auto;text-align:center">
#       8     <div>Latent Trajectory</div>
# ----> 9     <video src="{mp4_path_latent}" controls style="min-width:240px; max-width:240px; height:auto;"></video>
#      10   </div>
#      11 </div>
#      12 """
#      13 display(HTML(html))
#
# NameError: name 'mp4_path_latent' is not defined

# %%
cls_traj_2d = twoD_projection(cls_traj)
idxs = np.arange(cls_traj_2d.shape[0])

plt.figure(figsize=(6,6))
# faint line connecting points
plt.plot(cls_traj_2d[:,0], cls_traj_2d[:,1], color='lightgray', linewidth=1, zorder=1)
# colored points showing order
sc = plt.scatter(cls_traj_2d[:,0], cls_traj_2d[:,1], c=idxs, cmap='plasma', s=60, zorder=2)
plt.colorbar(sc, label='timestep')
# optional labels (can remove if cluttered)
for i in range(0, cls_traj_2d.shape[0], 5):
    plt.annotate(
        str(i),
        (cls_traj_2d[i,0], cls_traj_2d[i,1]),
        xytext=(5, 5),
        textcoords='offset points',
        fontsize=9,
        fontweight='bold',
        # ha='right',
        # va='bottom',
        bbox=dict(facecolor='white', alpha=0.7, edgecolor='none', pad=1)
    )

plt.title("Trajectory in Visual CLS Embedding Space (2D Projection)")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 cls_traj_2d = twoD_projection(cls_traj)
#       2 idxs = np.arange(cls_traj_2d.shape[0])
#       4 plt.figure(figsize=(6,6))
#
# Cell In[37], line 5, in twoD_projection(cls_traj)
#       3 def twoD_projection(cls_traj):
#       4     tsne = TSNE(n_components=2, perplexity=10, random_state=0)
# ----> 5     return tsne.fit_transform(cls_traj.numpy())
#
# AttributeError: 'list' object has no attribute 'numpy'

# %% [markdown]
# rollout

# %%
# multi step rollout from a real trajectory autoregressive predictions
horizon = 50
start_idx = 10
true_proprio, decoded_predicted_proprio = [], []
true_img, decoded_predicted_img = [], []
with torch.no_grad():
    # initialize with true state
    proprio = trajectory[start_idx][0].unsqueeze(0).to(device)
    img = trajectory[start_idx][1].unsqueeze(0).to(device)
    
    for t in range(horizon):
        # store true states
        true_proprio.append(trajectory[start_idx + t][0].unsqueeze(0).cpu())
        true_img.append(trajectory[start_idx + t][1].unsqueeze(0).cpu())
        
        # encode current state
        with torch.amp.autocast(dtype=torch.float16, device_type=device.type):
            cls, patches, _ = visual_encoder.visual_encoder(img)
            proprio_enc = visual_encoder.proprio_encoder(proprio)
        
        # get action to next state from dataset
        action = dataset[start_idx + t][1].unsqueeze(0).to(device)
        action_enc = visual_encoder.action_encoder(action)
        
        # predict next state
        with torch.amp.autocast(dtype=torch.float16, device_type=device.type):
            pred_cls, pred_patches, pred_proprio = visual_encoder.predictor(
                cls, patches, proprio_enc, action_enc
            )
            pred_cls += cls
            pred_patches += patches
            pred_proprio += proprio_enc
            
            # decode predicted next state
            decoded_proprio = visual_encoder.proprio_decoder(pred_proprio).float()
            decoded_img = visual_encoder.visual_decoder(pred_patches, pred_cls, pred_proprio).float()
        
        # store predicted states
        decoded_predicted_proprio.append(decoded_proprio.cpu())
        decoded_predicted_img.append(decoded_img.cpu())
        
        # update current state for next iteration
        proprio = decoded_proprio
        img = decoded_img

# Stack results
true_proprio = torch.cat(true_proprio, dim=0)
decoded_predicted_proprio = torch.cat(decoded_predicted_proprio, dim=0)
true_img = torch.cat(true_img, dim=0)
decoded_predicted_img = torch.cat(decoded_predicted_img, dim=0)
# Out:
# ---------------------------------------------------------------------------
# TorchRuntimeError                         Traceback (most recent call last)
# Cell In[41], line 18
#      16 # encode current state
#      17 with torch.amp.autocast(dtype=torch.float16, device_type=device.type):
# ---> 18     cls, patches, _ = visual_encoder.visual_encoder(img)
#      19     proprio_enc = visual_encoder.proprio_encoder(proprio)
#      21 # get action to next state from dataset
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:375, in OptimizedModule.__call__(self, *args, **kwargs)
#     365 if torch.nn.modules.module._has_any_global_hook():
#     366     warnings.warn(
#     367         "Using `torch.compile(module)` when there are global hooks on "
#     368         "modules (e.g., from `register_module_forward_hook`); this will"
#    (...)    373         stacklevel=2,
#     374     )
# --> 375 return super().__call__(*args, **kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:736, in _TorchDynamoContext.__call__.<locals>.compile_wrapper(*args, **kwargs)
#     733 _maybe_set_eval_frame(_callback_from_stance(callback))
#     735 try:
# --> 736     return fn(*args, **kwargs)
#     737 except Unsupported as e:
#     738     if config.verbose:
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:1495, in CatchErrorsWrapper.__call__(self, frame, cache_entry, frame_state)
#    1489             return hijacked_callback(
#    1490                 frame, cache_entry, self.hooks, frame_state
#    1491             )
#    1493 with compile_lock, _disable_current_modes():
#    1494     # skip=1: skip this frame
# -> 1495     return self._torchdynamo_orig_callable(
#    1496         frame, cache_entry, self.hooks, frame_state, skip=1
#    1497     )
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:1272, in ConvertFrame.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#    1270 counters["frames"]["total"] += 1
#    1271 try:
# -> 1272     result = self._inner_convert(
#    1273         frame, cache_entry, hooks, frame_state, skip=skip + 1
#    1274     )
#    1275     counters["frames"]["ok"] += 1
#    1276     return result
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:629, in ConvertFrameAssert.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#     626     dynamo_tls.traced_frame_infos.append(info)
#     628 with compile_context(CompileContext(compile_id)):
# --> 629     return _compile(
#     630         frame.f_code,
#     631         frame.f_globals,
#     632         frame.f_locals,
#     633         frame.f_builtins,
#     634         frame.closure,
#     635         self._torchdynamo_orig_callable,
#     636         self._one_graph,
#     637         self._export,
#     638         self._export_constraints,
#     639         hooks,
#     640         cache_entry,
#     641         cache_size,
#     642         frame,
#     643         frame_state=frame_state,
#     644         compile_id=compile_id,
#     645         skip=skip + 1,
#     646         package=self._package,
#     647     )
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:1111, in _compile(code, globals, locals, builtins, closure, compiler_fn, one_graph, export, export_constraints, hooks, cache_entry, cache_size, frame, frame_state, compile_id, skip, package)
#    1109 guarded_code = None
#    1110 try:
# -> 1111     guarded_code = compile_inner(code, one_graph, hooks, transform)
#    1113     # NB: We only put_code_state in success case.  Success case here
#    1114     # does include graph breaks; specifically, if a graph break still
#    1115     # resulted in a partially compiled graph, we WILL return here.  An
#    (...)   1120     # to upload for graph break though, because this can prevent
#    1121     # extra graph break compilations.)
#    1122     put_code_state()
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_utils_internal.py:97, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#      94 # This is not needed but we have it here to avoid having profile_compile_time
#      95 # in stack traces when profiling is not enabled.
#      96 if not StrobelightCompileTimeProfiler.enabled:
# ---> 97     return function(*args, **kwargs)
#      99 return StrobelightCompileTimeProfiler.profile_compile_time(
#     100     function, phase_name, *args, **kwargs
#     101 )
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:793, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     787     stack.enter_context(
#     788         torch._dynamo.callback_handler.install_callbacks(
#     789             CallbackTrigger.DYNAMO, str(CompileContext.current_compile_id())
#     790         )
#     791     )
#     792     stack.enter_context(CompileTimeInstructionCounter.record())
# --> 793     return _compile_inner(code, one_graph, hooks, transform)
#     795 return (
#     796     ConvertFrameReturn()
#     797 )
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:832, in _compile.<locals>._compile_inner(code, one_graph, hooks, transform)
#     828 try:
#     829     with dynamo_timed(
#     830         f"compile_attempt_{attempt}", log_pt2_compile_event=True
#     831     ):
# --> 832         out_code = transform_code_object(code, transform)
#     833     break
#     834 except exc.RestartAnalysis as e:
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/bytecode_transformation.py:1424, in transform_code_object(code, transformations, safe)
#    1421 instructions = cleaned_instructions(code, safe)
#    1422 propagate_line_nums(instructions)
# -> 1424 transformations(instructions, code_options)
#    1425 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:267, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     265 exit_stack.enter_context(torch_function_mode_stack_state_mgr)
#     266 try:
# --> 267     return fn(*args, **kwargs)
#     268 finally:
#     269     cleanup.close()
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:753, in _compile.<locals>.transform(instructions, code_options)
#     751     tracer.output.mark_bytecode_tracing_start()
#     752     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 753         tracer.run()
#     754 except exc.UnspecializeRestartAnalysis:
#     755     speculation_log.clear()  # type: ignore[has-type]
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:3497, in InstructionTranslator.run(self)
#    3496 def run(self):
# -> 3497     super().run()
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1363, in InstructionTranslatorBase.run(self)
#    1361     self.output.push_tx(self)
#    1362     self.start_point = self.instruction_pointer
# -> 1363     while self.step():
#    1364         pass
#    1365 except TensorifyScalarRestartAnalysis:
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1267, in InstructionTranslatorBase.step(self)
#    1264 self.update_block_stack(inst)
#    1266 try:
# -> 1267     self.dispatch_table[inst.opcode](self, inst)
#    1268     return not self.output.should_exit
#    1269 except TensorifyScalarRestartAnalysis:
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:834, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     832     return handle_graph_break(self, inst, speculation.reason)
#     833 try:
# --> 834     return inner_fn(self, inst)
#     835 except Unsupported as excp:
#     836     if self.active_generic_context_managers:
#     837         # We don't support graph break under GenericContextWrappingVariable,
#     838         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:2910, in InstructionTranslatorBase.CALL(self, inst)
#    2908 @break_graph_if_unsupported(push=1)
#    2909 def CALL(self, inst):
# -> 2910     self._call(inst)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:2904, in InstructionTranslatorBase._call(self, inst, call_kw)
#    2899     kwargs = {}
#    2901 try:
#    2902     # if call_function fails, need to set kw_names to None, otherwise
#    2903     # a subsequent call may have self.kw_names set to an old value
# -> 2904     self.call_function(fn, args, kwargs)
#    2905 finally:
#    2906     self.kw_names = None
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1193, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#    1191 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#    1192     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# -> 1193 self.push(fn.call_function(self, args, kwargs))
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/lazy.py:201, in _create_realize_and_forward.<locals>.realize_and_forward(self, *args, **kwargs)
#     197 @functools.wraps(getattr(VariableTracker, name))
#     198 def realize_and_forward(
#     199     self: LazyVariableTracker, *args: Any, **kwargs: Any
#     200 ) -> Any:
# --> 201     return getattr(self.realize(), name)(*args, **kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/nn_module.py:1000, in UnspecializedNNModuleVariable.call_function(self, tx, args, kwargs)
#     992 ctx = (
#     993     record_nn_module_stack(
#     994         str(id(mod)), self.get_nn_module_stack_source(), tx, mod
#    (...)    997     else nullcontext()
#     998 )
#     999 with ctx:
# -> 1000     return variables.UserFunctionVariable(fn, source=source).call_function(
#    1001         tx, [self] + list(args), kwargs
#    1002     )
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/functions.py:529, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     527         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     528             return super().call_function(tx, args, kwargs)
# --> 529 return super().call_function(tx, args, kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/functions.py:293, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     287 def call_function(
#     288     self,
#     289     tx: "InstructionTranslator",
#     290     args: "list[VariableTracker]",
#     291     kwargs: "dict[str, VariableTracker]",
#     292 ) -> "VariableTracker":
# --> 293     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1210, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#    1208     return self.inline_generator_function(fn, args, kwargs)
#    1209 else:
# -> 1210     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:3698, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3696 with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
#    3697     tracer = cls.build_inline_tracer(parent, func, args, kwargs)
# -> 3698     return tracer.inline_call_()
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:3901, in InliningInstructionTranslator.inline_call_(self)
#    3899 try:
#    3900     with strict_ctx:
# -> 3901         self.run()
#    3902 except exc.ObservedException as e:
#    3903     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1363, in InstructionTranslatorBase.run(self)
#    1361     self.output.push_tx(self)
#    1362     self.start_point = self.instruction_pointer
# -> 1363     while self.step():
#    1364         pass
#    1365 except TensorifyScalarRestartAnalysis:
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1267, in InstructionTranslatorBase.step(self)
#    1264 self.update_block_stack(inst)
#    1266 try:
# -> 1267     self.dispatch_table[inst.opcode](self, inst)
#    1268     return not self.output.should_exit
#    1269 except TensorifyScalarRestartAnalysis:
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:834, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     832     return handle_graph_break(self, inst, speculation.reason)
#     833 try:
# --> 834     return inner_fn(self, inst)
#     835 except Unsupported as excp:
#     836     if self.active_generic_context_managers:
#     837         # We don't support graph break under GenericContextWrappingVariable,
#     838         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:2910, in InstructionTranslatorBase.CALL(self, inst)
#    2908 @break_graph_if_unsupported(push=1)
#    2909 def CALL(self, inst):
# -> 2910     self._call(inst)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:2904, in InstructionTranslatorBase._call(self, inst, call_kw)
#    2899     kwargs = {}
#    2901 try:
#    2902     # if call_function fails, need to set kw_names to None, otherwise
#    2903     # a subsequent call may have self.kw_names set to an old value
# -> 2904     self.call_function(fn, args, kwargs)
#    2905 finally:
#    2906     self.kw_names = None
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1193, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#    1191 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#    1192     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# -> 1193 self.push(fn.call_function(self, args, kwargs))
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/lazy.py:201, in _create_realize_and_forward.<locals>.realize_and_forward(self, *args, **kwargs)
#     197 @functools.wraps(getattr(VariableTracker, name))
#     198 def realize_and_forward(
#     199     self: LazyVariableTracker, *args: Any, **kwargs: Any
#     200 ) -> Any:
# --> 201     return getattr(self.realize(), name)(*args, **kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/nn_module.py:1000, in UnspecializedNNModuleVariable.call_function(self, tx, args, kwargs)
#     992 ctx = (
#     993     record_nn_module_stack(
#     994         str(id(mod)), self.get_nn_module_stack_source(), tx, mod
#    (...)    997     else nullcontext()
#     998 )
#     999 with ctx:
# -> 1000     return variables.UserFunctionVariable(fn, source=source).call_function(
#    1001         tx, [self] + list(args), kwargs
#    1002     )
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/functions.py:529, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     527         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     528             return super().call_function(tx, args, kwargs)
# --> 529 return super().call_function(tx, args, kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/functions.py:293, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     287 def call_function(
#     288     self,
#     289     tx: "InstructionTranslator",
#     290     args: "list[VariableTracker]",
#     291     kwargs: "dict[str, VariableTracker]",
#     292 ) -> "VariableTracker":
# --> 293     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1210, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#    1208     return self.inline_generator_function(fn, args, kwargs)
#    1209 else:
# -> 1210     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:3698, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3696 with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
#    3697     tracer = cls.build_inline_tracer(parent, func, args, kwargs)
# -> 3698     return tracer.inline_call_()
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:3901, in InliningInstructionTranslator.inline_call_(self)
#    3899 try:
#    3900     with strict_ctx:
# -> 3901         self.run()
#    3902 except exc.ObservedException as e:
#    3903     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1363, in InstructionTranslatorBase.run(self)
#    1361     self.output.push_tx(self)
#    1362     self.start_point = self.instruction_pointer
# -> 1363     while self.step():
#    1364         pass
#    1365 except TensorifyScalarRestartAnalysis:
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1267, in InstructionTranslatorBase.step(self)
#    1264 self.update_block_stack(inst)
#    1266 try:
# -> 1267     self.dispatch_table[inst.opcode](self, inst)
#    1268     return not self.output.should_exit
#    1269 except TensorifyScalarRestartAnalysis:
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:834, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     832     return handle_graph_break(self, inst, speculation.reason)
#     833 try:
# --> 834     return inner_fn(self, inst)
#     835 except Unsupported as excp:
#     836     if self.active_generic_context_managers:
#     837         # We don't support graph break under GenericContextWrappingVariable,
#     838         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:2910, in InstructionTranslatorBase.CALL(self, inst)
#    2908 @break_graph_if_unsupported(push=1)
#    2909 def CALL(self, inst):
# -> 2910     self._call(inst)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:2904, in InstructionTranslatorBase._call(self, inst, call_kw)
#    2899     kwargs = {}
#    2901 try:
#    2902     # if call_function fails, need to set kw_names to None, otherwise
#    2903     # a subsequent call may have self.kw_names set to an old value
# -> 2904     self.call_function(fn, args, kwargs)
#    2905 finally:
#    2906     self.kw_names = None
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1193, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#    1191 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#    1192     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# -> 1193 self.push(fn.call_function(self, args, kwargs))
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/nn_module.py:1000, in UnspecializedNNModuleVariable.call_function(self, tx, args, kwargs)
#     992 ctx = (
#     993     record_nn_module_stack(
#     994         str(id(mod)), self.get_nn_module_stack_source(), tx, mod
#    (...)    997     else nullcontext()
#     998 )
#     999 with ctx:
# -> 1000     return variables.UserFunctionVariable(fn, source=source).call_function(
#    1001         tx, [self] + list(args), kwargs
#    1002     )
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/functions.py:529, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     527         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     528             return super().call_function(tx, args, kwargs)
# --> 529 return super().call_function(tx, args, kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/functions.py:293, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     287 def call_function(
#     288     self,
#     289     tx: "InstructionTranslator",
#     290     args: "list[VariableTracker]",
#     291     kwargs: "dict[str, VariableTracker]",
#     292 ) -> "VariableTracker":
# --> 293     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1210, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#    1208     return self.inline_generator_function(fn, args, kwargs)
#    1209 else:
# -> 1210     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:3698, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3696 with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
#    3697     tracer = cls.build_inline_tracer(parent, func, args, kwargs)
# -> 3698     return tracer.inline_call_()
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:3901, in InliningInstructionTranslator.inline_call_(self)
#    3899 try:
#    3900     with strict_ctx:
# -> 3901         self.run()
#    3902 except exc.ObservedException as e:
#    3903     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1363, in InstructionTranslatorBase.run(self)
#    1361     self.output.push_tx(self)
#    1362     self.start_point = self.instruction_pointer
# -> 1363     while self.step():
#    1364         pass
#    1365 except TensorifyScalarRestartAnalysis:
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1267, in InstructionTranslatorBase.step(self)
#    1264 self.update_block_stack(inst)
#    1266 try:
# -> 1267     self.dispatch_table[inst.opcode](self, inst)
#    1268     return not self.output.should_exit
#    1269 except TensorifyScalarRestartAnalysis:
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:834, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     832     return handle_graph_break(self, inst, speculation.reason)
#     833 try:
# --> 834     return inner_fn(self, inst)
#     835 except Unsupported as excp:
#     836     if self.active_generic_context_managers:
#     837         # We don't support graph break under GenericContextWrappingVariable,
#     838         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:2910, in InstructionTranslatorBase.CALL(self, inst)
#    2908 @break_graph_if_unsupported(push=1)
#    2909 def CALL(self, inst):
# -> 2910     self._call(inst)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:2904, in InstructionTranslatorBase._call(self, inst, call_kw)
#    2899     kwargs = {}
#    2901 try:
#    2902     # if call_function fails, need to set kw_names to None, otherwise
#    2903     # a subsequent call may have self.kw_names set to an old value
# -> 2904     self.call_function(fn, args, kwargs)
#    2905 finally:
#    2906     self.kw_names = None
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1193, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#    1191 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#    1192     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# -> 1193 self.push(fn.call_function(self, args, kwargs))
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/functions.py:1055, in UserMethodVariable.call_function(self, tx, args, kwargs)
#    1053     fn = getattr(self.obj.value, self.fn.__name__)
#    1054     return invoke_and_store_as_constant(tx, fn, self.get_name(), args, kwargs)
# -> 1055 return super().call_function(tx, args, kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/functions.py:529, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     527         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     528             return super().call_function(tx, args, kwargs)
# --> 529 return super().call_function(tx, args, kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/functions.py:293, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     287 def call_function(
#     288     self,
#     289     tx: "InstructionTranslator",
#     290     args: "list[VariableTracker]",
#     291     kwargs: "dict[str, VariableTracker]",
#     292 ) -> "VariableTracker":
# --> 293     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1210, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#    1208     return self.inline_generator_function(fn, args, kwargs)
#    1209 else:
# -> 1210     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:3698, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3696 with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
#    3697     tracer = cls.build_inline_tracer(parent, func, args, kwargs)
# -> 3698     return tracer.inline_call_()
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:3901, in InliningInstructionTranslator.inline_call_(self)
#    3899 try:
#    3900     with strict_ctx:
# -> 3901         self.run()
#    3902 except exc.ObservedException as e:
#    3903     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1363, in InstructionTranslatorBase.run(self)
#    1361     self.output.push_tx(self)
#    1362     self.start_point = self.instruction_pointer
# -> 1363     while self.step():
#    1364         pass
#    1365 except TensorifyScalarRestartAnalysis:
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1267, in InstructionTranslatorBase.step(self)
#    1264 self.update_block_stack(inst)
#    1266 try:
# -> 1267     self.dispatch_table[inst.opcode](self, inst)
#    1268     return not self.output.should_exit
#    1269 except TensorifyScalarRestartAnalysis:
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:834, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     832     return handle_graph_break(self, inst, speculation.reason)
#     833 try:
# --> 834     return inner_fn(self, inst)
#     835 except Unsupported as excp:
#     836     if self.active_generic_context_managers:
#     837         # We don't support graph break under GenericContextWrappingVariable,
#     838         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:2910, in InstructionTranslatorBase.CALL(self, inst)
#    2908 @break_graph_if_unsupported(push=1)
#    2909 def CALL(self, inst):
# -> 2910     self._call(inst)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:2904, in InstructionTranslatorBase._call(self, inst, call_kw)
#    2899     kwargs = {}
#    2901 try:
#    2902     # if call_function fails, need to set kw_names to None, otherwise
#    2903     # a subsequent call may have self.kw_names set to an old value
# -> 2904     self.call_function(fn, args, kwargs)
#    2905 finally:
#    2906     self.kw_names = None
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1193, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#    1191 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#    1192     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# -> 1193 self.push(fn.call_function(self, args, kwargs))
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/lazy.py:201, in _create_realize_and_forward.<locals>.realize_and_forward(self, *args, **kwargs)
#     197 @functools.wraps(getattr(VariableTracker, name))
#     198 def realize_and_forward(
#     199     self: LazyVariableTracker, *args: Any, **kwargs: Any
#     200 ) -> Any:
# --> 201     return getattr(self.realize(), name)(*args, **kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/torch.py:1338, in TorchInGraphFunctionVariable.call_function(self, tx, args, kwargs)
#    1329 if "out" in kwargs and isinstance(kwargs["out"], variables.TensorVariable):
#    1330     # Calling fake tensor propagation can mutate the out= tensor in
#    1331     # tx.output.tracked_fakes. tracked_fakes are used to apply
#    (...)   1334     # guards. So save the shape now, and check later if it has
#    1335     # changed. If it has, graph break.
#    1336     fake_out_shape = kwargs["out"].proxy.node.meta["example_value"].shape
# -> 1338 tensor_variable = wrap_fx_proxy(
#    1339     tx=tx,
#    1340     proxy=tx.output.create_proxy(
#    1341         "call_function",
#    1342         fn_,
#    1343         *proxy_args_kwargs(args, kwargs),
#    1344     ),
#    1345 )
#    1347 # Handle e.g., `torch.ones(10, requires_grad=True)`
#    1348 if (
#    1349     isinstance(tensor_variable, TensorVariable)
#    1350     and "requires_grad" in kwargs
#    1351     and kwargs["requires_grad"].as_python_constant()
#    1352 ):
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/builder.py:2559, in wrap_fx_proxy(tx, proxy, example_value, subclass_type, **options)
#    2551 kwargs = {
#    2552     "tx": tx,
#    2553     "proxy": proxy,
#    (...)   2556     **options,
#    2557 }
#    2558 if subclass_type is None:
# -> 2559     return wrap_fx_proxy_cls(target_cls=TensorVariable, **kwargs)
#    2560 else:
#    2561     result = wrap_fx_proxy_cls(target_cls=TensorWithTFOverrideVariable, **kwargs)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/builder.py:2625, in wrap_fx_proxy_cls(target_cls, tx, proxy, example_value, subclass_type, **options)
#    2621 def wrap_fx_proxy_cls(
#    2622     target_cls, tx, proxy, example_value=None, subclass_type=None, **options
#    2623 ):
#    2624     if example_value is None:
# -> 2625         return _wrap_fx_proxy(
#    2626             target_cls, tx, proxy, example_value, subclass_type, **options
#    2627         )
#    2628     elif isinstance(example_value, torch.Tensor):
#    2629         return _wrap_fx_preexisting_tensor(
#    2630             target_cls, tx, proxy, example_value, subclass_type, **options
#    2631         )
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/variables/builder.py:2723, in _wrap_fx_proxy(target_cls, tx, proxy, example_value, subclass_type, **options)
#    2718 # See NOTE: [Deferring tensor pack/unpack hooks until runtime]
#    2719 with torch._dynamo.utils._disable_saved_tensors_hooks_during_tracing():
#    2720     # with preserve_rng_state():
#    2721     # only allow_non_graph_fake in this instance because we handle the non-fake
#    2722     # cases properly below.
# -> 2723     example_value = get_fake_value(proxy.node, tx, allow_non_graph_fake=True)
#    2725 return handle_traced_output(
#    2726     example_value, tx, proxy, options, subclass_type, target_cls
#    2727 )
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/utils.py:3355, in get_fake_value(node, tx, allow_non_graph_fake)
#    3347     elif isinstance(cause, TypeError) and "argument" in str(cause):
#    3348         unimplemented_v2(
#    3349             gb_type="TypeError when making fake tensor call",
#    3350             context=f"TypeError {node.target}: {cause}",
#    3351             explanation="",
#    3352             hints=[],
#    3353         )
# -> 3355     raise TorchRuntimeError(str(e)).with_traceback(e.__traceback__) from None
#    3357 if not allow_non_graph_fake:
#    3358     _ = pytree.tree_map_only(
#    3359         torch.Tensor, functools.partial(ensure_graph_fake, tx=tx), ret_val
#    3360     )
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/utils.py:3253, in get_fake_value(node, tx, allow_non_graph_fake)
#    3251 try:
#    3252     with tx.fake_mode, enable_python_dispatcher():
# -> 3253         ret_val = wrap_fake_exception(
#    3254             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    3255         )
#    3256 except Unsupported:
#    3257     raise
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/utils.py:2753, in wrap_fake_exception(fn)
#    2751 def wrap_fake_exception(fn):
#    2752     try:
# -> 2753         return fn()
#    2754     except UnsupportedFakeTensorException as e:
#    2755         from .exc import unimplemented_v2
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/utils.py:3254, in get_fake_value.<locals>.<lambda>()
#    3251 try:
#    3252     with tx.fake_mode, enable_python_dispatcher():
#    3253         ret_val = wrap_fake_exception(
# -> 3254             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    3255         )
#    3256 except Unsupported:
#    3257     raise
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/utils.py:3462, in run_node(tracer, node, args, kwargs, nnmodule)
#    3460         raise
#    3461     except Exception as e:
# -> 3462         raise RuntimeError(make_error_message(e)).with_traceback(
#    3463             e.__traceback__
#    3464         ) from e
#    3466 raise AssertionError(op)
#
# File ~/.conda/envs/py12/lib/python3.12/site-packages/torch/_dynamo/utils.py:3421, in run_node(tracer, node, args, kwargs, nnmodule)
#    3419 try:
#    3420     if op == "call_function":
# -> 3421         return node.target(*args, **kwargs)
#    3422     elif op == "call_method":
#    3423         if not hasattr(args[0], node.target):
#
# TorchRuntimeError: Dynamo failed to run FX node with fake tensors: call_function <built-in method conv2d of type object at 0x7ff66ed8b4a0>(*(FakeTensor(..., device='cuda:0', size=(1, 4)), Parameter(FakeTensor(..., device='cuda:0', size=(32, 3, 3, 3), requires_grad=True)), Parameter(FakeTensor(..., device='cuda:0', size=(32,), requires_grad=True)), (1, 1), (1, 1), (1, 1), 1), **{}): got RuntimeError('Expected 3D (unbatched) or 4D (batched) input to conv2d, but got input of size: [1, 4]')
#
# from user code:
#    File "/home/gabrielepintus/Documents/github/JEPA-Thesis/src/components/encoder.py", line 296, in forward
#     feat = self.stem(x)
#   File "/home/gabrielepintus/Documents/github/JEPA-Thesis/src/components/encoder.py", line 83, in forward
#     return self.net(x)  # (B, 64, 64, 64)
#   File "/home/gabrielepintus/.conda/envs/py12/lib/python3.12/site-packages/torch/nn/modules/container.py", line 244, in forward
#     input = module(input)
#   File "/home/gabrielepintus/.conda/envs/py12/lib/python3.12/site-packages/torch/nn/modules/conv.py", line 548, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/home/gabrielepintus/.conda/envs/py12/lib/python3.12/site-packages/torch/nn/modules/conv.py", line 543, in _conv_forward
#     return F.conv2d(
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"

# %%
proprio_error = (true_proprio - decoded_predicted_proprio).pow(2).sqrt()
fig, axes = plt.subplots(4, 1, figsize=(10, 8), sharex=True)
for i in range(4):
    axes[i].plot(proprio_error[:, i].cpu().numpy(), label=f'Joint {i+1} SE')
    axes[i].set_ylabel('Squared Error')
    axes[i].legend()
axes[-1].set_xlabel('Timestep')
plt.suptitle("Proprioceptive Prediction Squared Error over Rollout")
plt.show()

# %%
# Video of true vs predicted images over rollout
mp4_path_rollout = "rollout_true_vs_predicted.mp4"
fps = 3
with imageio.get_writer(
    mp4_path_rollout,
    fps=fps,
    codec='libx264',
    ffmpeg_params=['-crf', '0', '-preset', 'veryslow', '-pix_fmt', 'yuv444p']
) as writer:
    for t in range(horizon):
        # concatenate true and predicted images side by side
        true_img_t = true_img[t].permute(1,2,0).cpu().numpy()   # (H, W, 3), float [0,1]
        pred_img_t = decoded_predicted_img[t].permute(1,2,0).cpu().numpy()   # (H, W, 3), float [0,1]
        combined_img = np.concatenate([
            (true_img_t * 255).astype(np.uint8),
            (pred_img_t * 255).astype(np.uint8)
        ], axis=1)
        writer.append_data(combined_img)
HTML(f"""
<div style="text-align:center">
  <div>True (Left) vs Predicted (Right) Images over Rollout</div>
  <video src="{mp4_path_rollout}" controls style="min-width:480px; max-width:480px; height:auto;"></video>
</div>
""")
