# %%
import os
from envs.pointmaze import PointMazeEnv
from trajectory_generator import make_env
import matplotlib.pyplot as plt

os.environ["MUJOCO_GL"] = "egl"

# %%
env = make_env()

_ = env.reset()
frame = env.render()

plt.imshow(frame);
